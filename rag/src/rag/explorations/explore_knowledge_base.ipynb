# %%
import lancedb

db = lancedb.connect(uri = "../knowledge_base")
db
# Out:
# LanceDBConnection(uri='c:\\Users\\Lilit\\Documents\\GitHub\\RAG-demo\\rag\\src\\rag\\explorations\\..\\knowledge_base')

# %%
db["articles"]
# Out:
# LanceTable(name='articles', version=11, _conn=LanceDBConnection(uri='c:\\Users\\Lilit\\Documents\\GitHub\\RAG-demo\\rag\\src\\rag\\explorations\\..\\knowledge_base'))

# %%
db["articles"].to_pandas()
# Out:
#   document_name                                           filepath  \
# 0      fisk.txt  C:\Users\Lilit\Documents\GitHub\RAG-demo\rag\s...
# 1     kanin.txt  C:\Users\Lilit\Documents\GitHub\RAG-demo\rag\s...
# 2    krabba.txt  C:\Users\Lilit\Documents\GitHub\RAG-demo\rag\s...
# 3     panda.txt  C:\Users\Lilit\Documents\GitHub\RAG-demo\rag\s...
# 4     tiger.txt  C:\Users\Lilit\Documents\GitHub\RAG-demo\rag\s...
#
#                                              content embedding
# 0  Fiskar (Pisces) är en grupp vattenlevande rygg...      None
# 1  Harar och kaniner\n\nArtikel\nDiskussion\nLäs\...      None
# 2  Krabbor (Brachyura) är en delordning av vatten...      None
# 3  Jättepanda (Ailuropoda melanoleuca), panda, pa...      None
# 4  Tiger (Panthera tigris) är ett kattdjur som en...      None
